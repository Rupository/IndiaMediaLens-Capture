# %% [markdown]
# #### Imports

# %%
import pandas as pd

# %% [markdown]
# #### Load CSV

# %%
event = 'budget'

# %%
df = pd.read_csv(f'{event}_opinions.csv')

df
# Out:
#                                                      id  \
# 0     dcb0aeace54a4eff23c9fa6ea824da195afe2dbbff6148...
# 1     de3fffd04c4bec8454bd43003cb1e9bc92deeaac4f1a4d...
# 2     9aaf602fb8d9a150804dbd8676379d9727fd6e55aa44c5...
# 3     e46b484a77026ab8091d8496c007f9176be06f1aaab947...
# 4     f8d8a51bbfe30a3a9b83f52c369267982ec510974e53e6...
# ...                                                 ...
# 1034  f77ff60c0e84d1c984aba0163dc86797029034edc584a1...
# 1035  126a606b138921ecf4abaeb72aa9d68a9ab4281dbb66ca...
# 1036  d11d0ed653dd061b10117894aaa242ad0928c51d97b93a...
# 1037  f472c494049c2dc9d18a45b40ea64b17a7b19b4e311fe2...
# 1038  2ac064572e02826884ca6b86157ea0da491e5dd68e8752...
#
#                           indexed_date language          media_name  \
# 0     2025-07-02 15:45:32.191912+00:00       en  hindustantimes.com
# 1     2025-07-02 05:56:09.398395+00:00       en   indianexpress.com
# 2     2025-07-02 04:04:12.393744+00:00       en        dnaindia.com
# ...

# %%
df = df.dropna(subset=['Text'])

df
# Out:
#                                                      id  \
# 0     dcb0aeace54a4eff23c9fa6ea824da195afe2dbbff6148...
# 1     de3fffd04c4bec8454bd43003cb1e9bc92deeaac4f1a4d...
# 2     9aaf602fb8d9a150804dbd8676379d9727fd6e55aa44c5...
# 3     e46b484a77026ab8091d8496c007f9176be06f1aaab947...
# 4     f8d8a51bbfe30a3a9b83f52c369267982ec510974e53e6...
# ...                                                 ...
# 1034  f77ff60c0e84d1c984aba0163dc86797029034edc584a1...
# 1035  126a606b138921ecf4abaeb72aa9d68a9ab4281dbb66ca...
# 1036  d11d0ed653dd061b10117894aaa242ad0928c51d97b93a...
# 1037  f472c494049c2dc9d18a45b40ea64b17a7b19b4e311fe2...
# 1038  2ac064572e02826884ca6b86157ea0da491e5dd68e8752...
#
#                           indexed_date language          media_name  \
# 0     2025-07-02 15:45:32.191912+00:00       en  hindustantimes.com
# 1     2025-07-02 05:56:09.398395+00:00       en   indianexpress.com
# 2     2025-07-02 04:04:12.393744+00:00       en        dnaindia.com
# ...

# %%
df.to_csv(f'{event}_opinions.csv', index=False)
