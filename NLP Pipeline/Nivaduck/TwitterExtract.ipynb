# %%
from twikit import Client # pyright: ignore[reportMissingImports]

USERNAME = 'NA'
PASSWORD = 'NA'

client = Client('en-IN')

await client.login(
        auth_info_1=USERNAME,
        password=PASSWORD,
        cookies_file='cookies.json'
    )

user = await client.get_user_by_screen_name('elonmusk')
print(user.name)

# %%
import os
import pandas as pd
import requests
import time
from dotenv import load_dotenv
load_dotenv()

x_api_key = os.environ.get('X_API_KEY')

def get_display_name(username):
    time.sleep(0.05)
    url = "https://api.twitterapi.io/twitter/user/info"
    headers = {
        "X-API-Key": x_api_key
    }
    params = {
        "userName": username
    }
    
    response = requests.get(url, headers=headers, params=params)
    response.raise_for_status()
    
    data = response.json()

    try:
        display_name = data["data"]["name"]
        print(display_name)
        return display_name
    except:
        print("failed!")
        return pd.NA

# %%
df = pd.read_json('india_July_21.json')
df = df[df['party'] != 'To Be Added']

df

# %%
df_test = pd.DataFrame(df)
df_test['display_name'] = df_test['screen_name'].apply(get_display_name)

df_test

# %%
df_test.to_json('nivaduck_with_display_names.json')
df_test.to_csv('nivaduck_with_display_names.csv')

# %%
df_corpus = pd.read_json('nivaduck_with_display_names.json')
df_corpus = df_corpus.dropna(subset='display_name')

corpus = set(df_corpus['display_name'])
corpus.remove('')

corpus
# Out:
# {'Ncp Mira Bhaindar City District',
#  'Gopi Nath Pandey',
#  'Akhilesh Patidar Iyc',
#  'Shiv yadav',
#  'Afaque Ahmad Khan',
#  'Inc Bidar',
#  'Adv. Shivpal Ubnare',
#  'Akhilesh Chaudhary',
#  'Amarjeet Singh Raja (Modi Ka Pariwar)',
#  'Pankaj Thakur (BJP) (मोदी का परिवार)',
#  'Nanabhau Mohod',
#  'Pratap Baburao Sarnaik',
#  'param Desai',
#  'Prabhu ADMK-Say NoTo Drugs & Dmk',
#  'Sanjay Khambayate - संजय खंबायते',
#  'Rajajinagar AAP',
#  'Narender Nath Ex. MLA',
#  'V.H.Choudhary',
#  'Prafulla Kr. Mahanta',
#  'NSUI Live',
#  'hariom Prabhakar',
#  'Smriti Irani Office',
#  'chokidaar satya prakash dhakad',
#  'ABHISHEK BHARGAD🇮🇳',
#  'Asha Rathore.ITCell n social media district conven',
#  'Samadhan Sarvankar',
#  'Beninson cijo - Say No To Drugs & DMK',
#  'Gopal Vaghela',
#  '@Jaydeepmakwana09',
#  'Ravindra V Gaikwad',
#  'Sachchidanand Upasane FAN',
#  'Dhandev Thakur',
#  'Hadi Pranjal',
#  'Rajkumar Mev',
#  'Adv.Tej Pratap Singh & Associates',
#  'RAMRAO MAHALE BJP Ex MAL sausar',
#  'Ashok chavan @INC',
#  'Tahir Sayeed',
#  'Punitt Upadhyay(घृत कौशिक )',
#  'Kubendran P',
#  'Jaydeepsinh BJP',
#  '𝗥𝗮𝗷𝗲𝘀𝗵 𝗚𝗼𝗿 🇮🇳',
#  'Ranjit Ade🇮🇳',
#  'Sulochana Das',
#  'अमजद खान मुग़ल',
#  'Pandu Talapaneni',
#  'Capt.Amarinder Singh',
#  'Thiruverkadu S Udhaya Kumar',
#  'Jayashankar Naik',
#  'Ramesh Singh Thakur',
#  'P. Wilson -தமிழ்நாட்டை தலைகுனிய விட மாட்டேன்',
#  'Renu Singh',
#  'prayaggraj tillavat',
#  'Dinesh Phalke',
#  'suraj singh somvanshi',
#  'Anand H Shrivastav(modi ka parivar)',
#  'Sangeeta Kumari Singh Deo',
#  'Thomas Isaac',
#  'Parushuram B K',
#  'Mayengbam Leima (ꯂꯩꯃꯥ ꯁꯒꯣꯜꯁꯦꯝ)',
#  'Santosh Patel',
#  'DALBIR SINGH RANDHAWA',
#  'Narinder Wadhwa',
#  'Adv. Pushpak Bakshi #INC',
#  'NUR NEHAR (NURI)',
#  'Phaneesh',
#  'ச. செந்தமிழ் செல்வன்',
#  'Inayat Khan',
#  'Clyde Crasto',
#  'Arjun Maisuriya',
#  'BTMCongress',
#  'Dr Sanju Boruah',
#  'रमन सिंह आजाद',
#  'Dr. Ramesh Pandey.',
#  'P.M.Govindaraj',
#  'Yadu Nandan Patidar Mhow',
#  'Kusumlata Ramesh',
#  'Shrinivas Rudra (Modi Ka Parivar)',
#  'Swapnil Fukte - Offical',
#  'Rajesh Rathorre',
#  'Adv Devender Grewal',
#  'Mohammed Illiyas',
#  'Adnan Shaikh',
#  'Prashant Choudhary',
#  'Vidisha Congress Sevadal',
#  'Amit Wowsome',
#  'Pashupati Kumar Paras',
#  'Chhatra RJD, saharsa',
#  'Ankit Hardiya',
#  'ISHAQUE SHAIKH INAMDAR',
#  'ELA.PADMANABAN',
#  'Harish Kottawar_IYC',
#  'BJP Karauli',
#  'Scindia Dil Se',
#  'Bobbeeta Sharma',
#  'MAHESH A. CHAUDHARI',
#  'narender rathi',
#  'Dasari Nanda Kumar',
#  'Arti Meena (आरती मीना टोडाभीम)',
#  'Abhijit Chakraborty',
#  'ABHIJIT',
#  'Krishna Radhakrishnan',
#  '*IMRAN BHATI*',
#  'POOVAI AMEER.S (TTV IT WING)',
#  'TDP Gannavaram',
#  'BJP4Maharashtra 2019 (221+)',
#  'Karti P Chidambaram',
#  'Babu Ahir',
#  'Anil Kale',
#  'Sandip Sahu',
#  'Sowmyabhargav',
#  'இ.பி.கார்த்திக்',
#  'BJP Medical Cell',
#  'ChowkiDar Savan Barot',
#  'Tamijur Rahaman',
#  'Dr. Atal Pandey 🇮🇳 डॉ. अटल पाण्डेय',
#  'Nirala Chandan',
#  'Shaina Chudasama Munot',
#  'Pardeepchhabra15@gmail.com',
#  'Chowkidar Kamlesh Brahmbhatt',
#  'து.சுரேஷ் கீரப்பாக்கம் @Suresh DMK Party',
#  'सुलभ गोयदानी',
#  'Maheshbhai Bhuriya',
#  'Anil Goel',
#  'Dinesh P Jain',
#  'Bharat Barot',
#  'BJYM KARNAVATI',
#  'Elangovan Manickam',
#  'Md.Salim',
#  'Bharat-Nation With Difference',
#  'Satish Mahana',
#  'Shubham Dhikale 🇮🇳',
#  'Surendar Giri',
#  'Babu Khandade',
#  'Sayyed Aasif Ali',
#  'Harish Padhiyar',
#  'Bapurao Solankar - बापुराव सोलनकर',
#  'Dr. Pramod Sawant',
#  'Shailendra Thakor ( Modi ka Parivar )',
#  'உடுமலை உதயா',
#  'Aman Gupta',
#  'MAYELVAGANAN.G',
#  'Dr Sanket Thakur',
#  'Mimi chakraborty',
#  'KPCC, Minority Department',
#  'Naveen Singh Rajput!!(Baba)!!',
#  'BJP Navi Mumbai',
#  'NITISH YADAV KANNAUJ',
#  'BJP Thiruvannamalai',
#  'Debashree Bora',
#  'Diganta R Koch',
#  'Vijay Kanaujiya',
#  'Vishal Kachhadiya',
#  'Sharath Bachegowda',
#  'Dulu Ahmed',
#  'IT CELL Kussh Soni',
#  'Vikram Chauhatha',
#  'Soumya Mallick',
#  'Akash Yadav-आकाश यादव 🇮🇳',
#  'Mahesh Laharpure',
#  'Laxmikant Bunty Joshi',
#  'Thakur Sangeet Soam',
#  'DIPAK SHARMA',
#  'Amritha Ramakrishnan',
#  'sameer Khalid Khan',
#  'Manoj Patel mannu bhaiya',
#  'Prof.P.Kanagasabapathi',
#  'katta sudhakar reddy',
#  'Raviraj Zala',
#  'Sellur K Raju',
#  'Bharat Singh',
#  'Akshay Lakra',
#  'Pradeep kumar',
#  'Rajit 🇮🇳',
#  'Kuldip patil',
#  'Kanchan Khare',
#  'Dr.Pramod Rathod',
#  'Avinash MV',
#  'Nihalpatel',
#  'B M Sudhakar',
#  'Jayaraj',
#  'BJYM Bokaro JH',
#  'Parambans Singh Romana',
#  'S.D.SABEEN',
#  'காதர்பாட்சா முத்துராமலிங்கம்',
#  'PST 4 BHARAT',
#  'இராஜசேகரன்., தி.மு.க',
#  'Pujan Mehta.BJP.official',
#  'Ruchit bjp 1',
#  'Ritesh Soni',
#  'O. Panneerselvam',
#  'AAP',
#  'Gurjot Dhindsa',
#  'Marri Puru Reddy',
#  'Ketan Mohitkar',
#  'Prashant Panchal 🇮🇳',
#  'Rajni Mankotia',
#  'Raja Tamrakar rj🚩',
#  'surya2.0',
#  'C. Krishnakumar',
#  'Haider Abbas Rizvi (Raju)',
#  'Hamdulla Sayeed',
#  'Dattatreya Hosabale',
#  'Raunak Choudhari',
#  'Panchayati Raj and Drinking Water Department',
#  'Ram Sagar',
#  'Bjym Ankleshwar Taluko',
#  'Shilpa Sharma',
#  'Vijay Rana(मोदी का परिवार)',
#  'Sanjay Kelkar MLC',
#  'Priya Chaudhary',
#  'Ashwin upadhyay',
#  'Vikram Singh yadav',
#  'Nadege Comiti',
#  'Rohan Jain IYC',
#  'Shikha Singh Tiwari',
#  'JV Fans',
#  'Surajpal Gurjar BJP',
#  'RamChander Chauhan',
#  'Chowkidar BJYM Jamshedpur JH',
#  'Gujarat Information',
#  'Fairoz Khan',
#  'COMMISSIONERATE POLICE',
#  'Adv Nitin Rawat',
#  'Narayan Khan(Mohd. Nasir Qureshi)',
#  'Kunal Ghosh',
#  'Om Singh Rajpurohit',
#  'korungthang',
#  'Deepak Singh',
#  'ganesh shankar pandey',
#  'Snehal Savita Siddheshwar Doke Patil',
#  'राजेश शर्मा युवा कांग्रेस नेता',
#  'Shalini Thackeray',
#  'सोनू रपडी',
#  'Subhash Chandra',
#  'Mayur Jaiswal',
#  'SuhailShaikh #WithRG',
#  'Prasad Lad',
#  'Pandit Saurabh Chaturvedi',
#  'Kanbivad Ward BJP',
#  'Swapnil Shirsath',
#  'Irfan Shaikh',
#  'Akhil Sharma',
#  'Pankaj Jaiswal',
#  'Shobha Shivhare',
#  'राकेश कुशवाहा🇮🇳 🚩💪श्री राम का दीवाना🚩',
#  'SUHAS PANDIT',
#  'N.Subramanian.',
#  'Praveen Kumar Dixit',
#  'NSUI Daman & Diu',
#  'Raju P Nair',
#  'Pon G Karthikeyan',
#  'Deepak Bhattacharya',
#  'ராஜ குலோத்துங்கன்',
#  'Bharti Prapanna',
#  'Adv Aditya Katariya Jain',
#  'Parveen Gunjan',
#  'Krishna Mohan',
#  'Janak Bharti 🇮🇳',
#  'G Murugadassan',
#  'Saurabh Shukla',
#  'Goverdhan Singh Tanwar ,Talawadi',
#  'Amol Jadhav',
#  '🏴சு.மகிழரசன் - தமிழ்நாட்டை தலை குனிய விடமாட்டே 🚩',
#  'Bapi Pradhan',
#  'Bjp4luni',
#  'Hetal Patel',
#  'Baldev Thakur',
#  'Madhavi Agarwal',
#  'ABVP Konkan',
#  'Mohammad Akbar Lone',
#  'A.R.MAHALAKSHMI',
#  'Deepu Patidar',
#  'Sachin Bhor',
#  'Sudhir Kumar Pathak',
#  'नवनीत शर्मा (मोदी का परिवार)',
#  'AAPAKhilesh_MLA',
#  'Kiran K',
#  'Muniraju C Sarjapura',
#  'KT Ajmal',
#  'Nitin tiwari',
#  'Pankaj Seth',
#  'Atul Thakor🇮🇳',
#  'BJP Loganathan',
#  'Sravanthi Palvai',
#  'Raja Dewangan NSUI',
#  'Office of HBS',
#  'தென்னை மு.விசயாலயன்',
#  'Gaurav Gogoi',
#  'Pramod Mishra',
#  'Ut Khader',
#  'Dr.D.L.Vijay Kumar',
#  'Vishal Batra',
#  'Er Devinder Rana',
#  'iVishal Parmar',
#  'Jeeva.Kamaraj',
#  'Manish Engineer',
#  'Ashish Pandey',
#  'VISHAL GAUTTAM',
#  'Rajnish Goenka',
#  'SakShi VeRmA',
#  'Dr. Satish Chaturvedi',
#  'Nirmal Patel🇮🇳🇮🇳',
#  'Chennimalai P Sathish - Say No To Drugs & DMK',
#  'Valjibhai Danicha',
#  'Surinder Ambardar',
#  'Uttar krushna Nagar',
#  'Sukhchain singh',
#  'Madan sahni',
#  'BJP North Central Mumbai',
#  'MI Shanavas',
#  'Chowkidar Praful Patel',
#  'Lalaji Mendon',
#  'Poonamben Maadam',
#  'Shyama Prasad Behera',
#  'Shahruq Ahmed Namazi',
#  'Gaurav Pathak ABVP',
#  'Mofidul Hussain',
#  'Kailash Vijayvargiya',
#  'Sonu Khan',
#  'Sobha Surendran',
#  'Hitesh',
#  'Jagdish Oza BJP (Modi Ka Parivar)',
#  'Surender jhajhria',
#  'Amarjeet chawla',
#  'Uttam Sharma Butoliya',
#  'Md',
#  'Rajkumar advocate',
#  'சே.முஜிபுர் ரஹ்மான்',
#  'lohith.Manjunath',
#  'Hukum Singh Anjana 🙏 जय श्री श्याम 🙏',
#  'anilkumar',
#  'Chowkidar Simmi sharmaa',
#  'Harish Bhandirge (मोदी का परिवार)',
#  'Prakash Gudi',
#  'Akshat Singh',
#  'Abhishek Singhvi',
#  'Vijay Chomal (मोदी का परिवार )',
#  'Richpal Singh Mirdha',
#  'Adv. Virat Dedaniya',
#  'शरदचंद्रजी पवार साहेब सोशल मिडिया दौंड',
#  'DATTA CHAVAN',
#  'Mohammad Shahid',
#  'Sudhanshu Mishra',
#  'Rajendra Trivedi',
#  'Aman Mohie',
#  'Navdeep Bansal',
#  'Dr B.R Suresh babu',
#  'Shivam',
#  'ದರ್ಶನ್ ಜೈನ್ | Darshan Jain',
#  'Winner Bindra',
#  'Kiran Dhidhi',
#  'samir dey',
#  'Deepanshu Sagar',
#  'Sagar Bherua',
#  'Pankaj Malik',
#  'Sukhdeo Bhagat',
#  'Avanish Bhargava',
#  'Tineshwar Baghel',
#  'Praful Joshi',
#  'sheetal patil',
#  'Shyoraj Jivan Valmiki, INC',
#  'Pooja Brar',
#  'Akash Sharma',
#  'Rakesh Misra',
#  'Md Jakir Hussain',
#  'Anubhav Mohanty',
#  'Rajinder Beri',
#  'Fatima Shaheen BJP leader',
#  'RaJ KaMaL YadaV 🇮🇳',
#  'SENTHAMARAI KANNAN',
#  'Ram lakhan gurjar Dausa',
#  'Er.R.Thiru Murugan',
#  'chavda yuvraj',
#  'Vijay Kumar Pandey',
#  'Gurparvez Shellay Sandhu',
#  'निखिल वत्स (addy)',
#  'Adv Diliprao Sarnaik',
#  'G H Thippa Reddy',
#  'Pranjal Gogoi',
#  'PRJA Party Manipur',
#  'Office of Jason',
#  'AAPkaNanded',
#  'INC Andaman Nicobar',
#  'Jadeja Bapu',
#  'Debajyoti Sahoo',
#  'राहुल कुमार(🚩राष्ट्रीय स्वयंसेवक संघ🚩)',
#  'Sunil Yadav',
#  'Premnarayan Vishwakarma (मोदी का परिवार)',
#  'BJP IT CELL',
#  'KN Tripathi',
#  'surendrasingh rajput',
#  'shriram',
#  'ABVP Thane',
#  'Chinmoy Dhauria',
#  'Rajkumar Gupta',
#  'Dr Sanjay.G🇮🇳',
#  'Kamaljeet Sehrawat',
#  'Principal Mohammadali Kadri',
#  'Gouthu Sireesha',
#  'MAINUDDEEN BAGAWAN',
#  'Abhinandan Tyagi',
#  'INC Mahadevapura',
#  'SANJAY SINGH',
#  'Kanika Bajaj',
#  'SAJID HUNANI',
#  'YASHWANT CHOUHAN',
#  'Suryakant Mahadik',
#  'Kh:Raiz Atish',
#  'Ranjit Solanki',
#  'NSUI Bengaluru Rural',
#  'Manipur Pradesh Youth Congress',
#  'P.VELUCHAMY.MP',
#  'Atik Qureshi',
#  'Kunal Patil',
#  'Sidhartha Nath',
#  'Ajay ojha',
#  'Biswaranjan Mohanty',
#  'yogeshsaxena',
#  'Alma',
#  'Aslam Gurukkal',
#  'ABVP Himachal Pradesh',
#  'Ayush Sharma',
#  'Jabir',
#  'Annapurna Chaturvedi',
#  'Dharmender Malik',
#  'satham',
#  'Omkar singh markam',
#  'BJYM Kolhapur - भाजयुमो कोल्हापूर',
#  'राहुल राव',
#  'Proud Indian',
#  'Zaki Pathan',
#  'RAMBABU DHONTHAMALLA',
#  'Balu',
#  'Ravindra singh',
#  'Shivendrasinh',
#  'Arun Kumar Yadav',
#  'Rajesh Bharwad',
#  'Vishwa Nath Dixit',
#  'Selvaperunthagai K',
#  'Nisha Kalia',
#  'SFI Rajasthan',
#  'Praveen Maru',
#  'Natwar vyas',
#  'Prasenjit Das',
#  'गौरव शर्मा (बैरागी )',
#  'Er Benkatesh Raman',
#  'Juhie Singh',
#  'Dr.Harish mehra',
#  'BJD Deogarh',
#  'Ramakant Bhargava',
#  'Raja Singh',
#  'Arun Joseph',
#  'Perni Nani',
#  'Jay Pandya',
#  'Raj Kumar Grover',
#  'MLekhi office',
#  'Padama Ram Meghwal',
#  'Hemant Saraswat',
#  'கரூர்.மு ரவிக்குமார் திமுக',
#  'Sagar Patil',
#  'Sachin pandey MPYC',
#  'Dr Balbir Singh',
#  'Harish Ranawat',
#  'Ravindralodhi',
#  'Sanjay Govabhai Rabari',
#  'Professionals 4 Congress',
#  'vp dhone 🇮🇳',
#  'Alshifa Muhammed',
#  'Jitendra Singh Bisht (Jeet)',
#  'Santosh Kumar',
#  'Sumitraben Patel - MODI PARIVAR',
#  'Roshan Joseph',
#  'prabakaran dmk',
#  'Sumitra Dahiya BJP',
#  'Rajkumar Gangula',
#  'Vikash Singh Rajput',
#  'MP Youth Congress SIDHI',
#  'CHOWKIDAR SINGARAVEL BJP',
#  'Prakash Patel BJYM',
#  'Jayanti Swain',
#  'Yasin Saravaiya.4',
#  'INCNanded',
#  '🇮🇳Anoop Singh🇮🇳',
#  'NARESHBHAI DHAMMELIY',
#  'Krunal Maheshwari (मोदी का परिवार )',
#  'Anurag Dhiman',
#  'Sachin Gairola',
#  'Gaurav Ruparelia (Modi ka parivar)',
#  'Advt. Shambhu Suthar',
#  'R.P.GADHVI',
#  'Virendra Yadav',
#  'Chandrakant Handore',
#  'Mehulsinh Gadhvi',
#  'Jeyaganesh',
#  'Congressforbmc',
#  'Manish Tiwari IYC',
#  'Nasru Khan',
#  'BJP Yuva Morcha',
#  'Nimish jadhav',
#  'P Jayarajan',
#  'Subramanian Swamy',
#  'Randhir yadav',
#  'Pankaj Tiwarri',
#  'Aiadmk Muthukumar',
#  'Chinta Anuradha',
#  'Nyaj Mansuri CSS BANNER',
#  'Akassh Dilip Salve',
#  "Suresh Arya सुरेश आर्य 'SurajSinghArya'",
#  'salike srikanth',
#  'Ravi Subramanya L. A',
#  'M I Shiblee',
#  'Vijay Kumar Gupta - INC',
#  'Waqar Lone',
#  'Abhishek Gupta',
#  'nityanand tripathi',
#  'MalkajgiriLYC',
#  'Adeesh',
#  'Dhiru Singh',
#  'K C Venugopal',
#  'Mpyc Singrauli',
#  'BJP Kalyan',
#  'Sidharth Rao',
#  'Satendar yadav',
#  'Dr. Nisarg Bhatt 🇮🇳',
#  'Manoj Patel BJP',
#  'BRAJESH S JAGTAP',
#  'DYFI Kallumoodu Unit',
#  'Digvijaya Singh',
#  'Bjp4gandevi',
#  'Veerabhadrashastri Hiremath',
#  'Kartik Bhatt BJP',
#  'Paresh Manorama Nagar',
#  'Jashodaben parmar',
#  'Vipul Hansoti.',
#  'BJP Mira Bhayander supporters',
#  'Dr.Saeeda Khan ڈاکٹر سعیدہ خان डॉ. सईदा खान',
#  'Indore Congress Sevadal',
#  'Kathiravan',
#  'Ranvir Ravi Kulrian',
#  'Salman Khan',
#  'Mmhonlumo Kikon',
#  'Suraj Sawant',
#  'Jay Gajjar',
#  "Abhay Pratap singh 'pappan'",
#  'Ratnesh Ojha',
#  'BJPITSM4dhoraji',
#  'avimaled',
#  'Jiten Gajaria',
#  'Nighat Abbass🇮🇳',
#  'K Naveen Kumar',
#  'Santosh Srivastava (मोदी का परिवार)',
#  'Ishaq Koreja',
#  'Ashokkumar',
#  'A.H.ANAND',
#  'Adv J.R. Padmakumar',
#  'MyGov Assam',
#  'Congress Live',
#  'பசும்பொன் பாலா',
#  'Ghulam Mohammad Saroori',
#  'Tirupati Kondhekar',
#  'Mahadev  wakde',
#  'Naynaben Rajyaguru',
#  'Abhijeet Subhash Chavan',
#  'K. Vijay Kumar',
#  'sofiqul islam',
#  'Mangubhai Patel',
#  'Navjeet Singh',
#  'Ramesh Dubey bhind',
#  'Praveen dmk',
#  'kishore Dhuldhoye',
#  'Anil Saini',
#  'Purnchandra Padhi/Coco',
#  'Vinod Mishra',
#  'SRVishnu 🇮🇳',
#  'Mukesh Nayak',
#  'Madhu Goud Yaskhi',
#  'Siddhrajsinh Chauhan',
#  'IT CELL ASARWA',
#  'भाजपा युवा मोर्चा, जयपुर',
#  'Bidyut dutta',
#  'SHIVANI KITEY',
#  '🇮🇳 Narendra patel',
#  'Yash Jilta',
#  'Jhunjhunu Sevadal',
#  'Chiranjivi Mateti',
#  'Ambarish Rai',
#  'Aiadmk IT Trichy Urban',
#  'manikandan',
#  'satheeshkumar',
#  'Faisal Meman',
#  'Anish Kumar Verma',
#  'मुकेश माली NSUI',
#  'Kumutha Raman',
#  'Hitendra Gandhi 🇮🇳',
#  'Shember Singh Gahlay',
#  'Mastan Singh',
#  'Pankaj Tripathi',
#  '/\\/\\AnO J   °|°iWaRi',
#  'Kuldeep Singh Gadrana',
#  'Kausar Ahemad Gulati▶️',
#  'Sandeep Sati',
#  'Deeptii Siingh',
#  'SANWAR MAL AGRAWAL',
#  'JyothiKumar Chamakkala',
#  'Ashok Kumar Goyal',
#  '𝔻𝕚𝕟𝕖𝕤𝕙 𝕋𝕪𝕒𝕘𝕚 🚩',
#  'Raviya Gaurav 🇮🇳',
#  'Dean Kuriakose',
#  'Shailesh Mehta(Sotta)',
#  'Techi Tadap Tara',
#  'haren',
#  'Varsha Chaudhari',
#  'Gopal Yadav',
#  'Avinash Dash',
#  'Rajeev Khandelwal',
#  'Shriram Richhariya',
#  'piyush shukla',
#  'Raman Malik🇮🇳 (मोदी का परिवार)',
#  'Ambuj Kumar',
#  '💝🌹💖🇮🇳jaggirmRanbir🇮🇳💖🌹💝',
#  'Dr. Vitthal Pawde',
#  'Abdul Azeez Hejamady',
#  'Killai K.Kanthan',
#  'BJP Dholpur',
#  'ஸ்ரீதர்கலை மணிகண்டன்',
#  'Uday Singh',
#  'Savita Deewan Sharma',
#  'Sunil D Bangera',
#  'Sushil Pandey',
#  'Simanta deka',
#  'Balakrishna Kandhikanti (Modi Ka Parivar)',
#  'MOHAN.V',
#  'Gaurav Chaudhary',
#  'Bjp Jamnagar Mahila Morcho',
#  'BJP 10 Nagaon LP',
#  'ABVP Mumbai University',
#  'Gopalshah',
#  'Anurag Nema',
#  'Sahilsinh Vihol',
#  'Ramesh Ahir',
#  'Ministry of Rural Development, Government of India',
#  'Maninder Singh',
#  'Begusarai Youth Congress',
#  'Rajeev Narang',
#  'JMM Gumla',
#  'vasant malani',
#  'Rajkot BJP',
#  'नरपत सिंह कोटड़ी',
#  'Janjgir',
#  'Parth Patel',
#  'Milan Ravat',
#  'S Muhamad Mydeen B.Sc.,MBA(UK)',
#  'Rajneesh Kimta',
#  'C S Puttaraju',
#  'Sourabh tiwari',
#  'Saurabh Dubey,Pransu',
#  'Veronica Patekar',
#  'Suresh Chaudhary bjp Jadiyali',
#  'Kapil Bhardwaj',
#  'vishantheru',
#  'Shakil lucky',
#  'திருச்சிமாவட்டதிமுக⏺',
#  'Aeshwarya Raj Singh',
#  'shubham samadhiya',
#  'P. K. Sindhav',
#  'South Goa Congress Sevadal',
#  'Office Of BJYM Sikkim',
#  'Saruk Yura',
#  'Aditya N Singh',
#  'Prathvi raghuwanshi',
#  'Somireddy ',
#  'Rajesh Sharma ।ৰাজেশ শৰ্মা ।રાજેશ શર્મા 🇮🇳',
#  'Bhuneshwar Patel#CGYCSM',
#  'RAMBABU YADAV',
#  'Ashish Jaiswal',
#  'Divyarajsinh Vaghela',
#  'Harshit V Desai',
#  'कुलदीप सिंह',
#  'West Bengal Pradesh Mahila Congress',
#  'Abdul Khalek Sheikh',
#  'Rishabh Garg',
#  'குன்னம் சட்டமன்றத்தொகுதி தி.மு.க.',
#  'Binay Kumar Choubey BJP',
#  'Vijay Singh Lakonda',
#  'Anuruddh Prtap Singh',
#  'Dr. Dharambir Agnihotri',
#  'Dharma Puduvayal',
#  'Shalini Yadav',
#  'Sushree Ankita',
#  'Meraj Wali AFRIDI',
#  'பெ.செந்தில்குமார் ME',
#  'King Rules',
#  'Lucky Singh',
#  'V G Gnanaprakash',
#  'Moumita Mukherjee',
#  'Narender Thakur',
#  'Virendra mishra',
#  'shwetabajpaikadam',
#  'தகவல் தொழில்நுட்ப அணி விருத்தாசலம் தொகுதி',
#  'जागरूक भारतीय नितिन',
#  'Selvaraj magesh',
#  'CM of Karnataka',
#  'Ajneet Singh Ghumman',
#  'Rshmi Khetrapal',
#  'Sanjay Saraf',
#  'Kamal Thakur',
#  'Prashant Babar',
#  'Office Of Rohit Pawar',
#  'PREM TANDI| प्रेम तांडी।',
#  'Jaideep Sharma',
#  'Sanjay Singh',
#  'Pawan Kashaudhan',
#  'Congress kaman',
#  'Maharashtra Pradesh Mahila Congress',
#  'Ravi Limbachiya',
#  'Harekrushna Khuntia',
#  'Nalini Barot',
#  'Anil Kokil',
#  'SPICES BOARD INDIA',
#  'm.p muralikrishnan',
#  'Tripura Pradesh Youth Congress',
#  'Karunesh Sharma',
#  'M N Habib@Sahil Habib ساحِل حبیب',
#  'Somnath Munda',
#  'SAMBASHIVARAO MASHIRAPU (M.S.SHIVA RAO)',
#  'Dharmendar Prajapati',
#  'Sukhnandan Chouhan',
#  'Mr. Mahi Shrivastava #सनातनी',
#  'Kamlesh Acharya(हिंदू)',
#  'senthi_itwingdmk',
#  'BJP4Odisha',
#  'Jitu Jirati (Jitendra)',
#  'DHIRAJ SINGH',
#  'NISHKANT PARKASH',
#  'SHANTARAM NAIK ex MP',
#  'Sureshgowda',
#  'Dattatraya Kulkarni (Modi Ka Pariwar)',
#  'S.Pravinaa-(Ph-D).. AIADMK',
#  'JaganFansUSA',
#  'Harshit soni (ਖੁਸ਼ਹਾਲ ਸੋਨੀ)',
#  'Chowkidar Balbir Thakur',
#  'sandip more',
#  'Richa Pandey Mishra (Modi Ka Pariwar)',
#  '𝐀𝐚𝐬𝐡𝐢𝐬𝐡 𝐃𝐞𝐨 𝐬𝐨𝐧𝐢 🇮🇳',
#  'Gokul Butail',
#  'Prahlad Gurjar',
#  'Dr Rajendra Moond',
#  'NSUI Gujarat',
#  'MuraliKrishnaPrasad',
#  'Budhi Singh Thakur',
#  'sahabdeen',
#  'Kamlesh Yadav',
#  'Sunita Duggal ,Former MP',
#  'Chamoli Congress Sevadal',
#  'BJD Rayagada',
#  'Somesh Sahu',
#  'YSRCP Srikakulam',
#  'Karthick KT',
#  'Pandiammk',
#  'Annapurna Mishra',
#  'Jay Mankani',
#  'Raigad IT sena',
#  'Yashodhar Desai',
#  'Hasmukh Patel',
#  'Abul Fajal',
#  'Aman Sharma',
#  'Asker. Cheekkilottu',
#  'Rafiqul islam',
#  'Nandita Nayak🇮🇳',
#  'Pauri Garhwal Congress Sevadal',
#  'Satish Dillonwali',
#  'CMO Haryana',
#  'Kunal Rathod',
#  'Dr. K. Surender Raj',
#  'Manoj Kumar',
#  'Palladam MLA',
#  'Manas DM',
#  'Kasturi Mohapatra',
#  'Sona PS / சொனாமகன்',
#  'Virendra Pandey 🙏',
#  'M S DEEPAK',
#  'Prashank_patel_bishnoi',
#  'Rahul Pustode',
#  'RAJEEV TIWARI JBP',
#  'Thammesh Gowda Hc',
#  'BJP MAHESWARAN BALAKRISHNAN (மோடியின் குடும்பம்)',
#  'Er. Anmol Katyal',
#  'Ashvin Patel',
#  'Nagatarathna H Indira',
#  'Mohit Pandya',
#  'Sanju Yadav राष्ट्रीय कांग्रेस पार्टी मध्य प्रदेश',
#  'Diwakar Singh (Pankaj bhaiya)',
#  'lavji Sorathia',
#  'BJP REWA',
#  'Bahraich Congress Sevadal',
#  'Ram Lakhan Yadav Adv.',
#  'Harjit Singh King',
#  'Ankeet Patel',
#  'Abhishek dhawan ( Modi Ka Parivar)',
#  'ब्लॉक अध्यक्ष चम्बा करतार ठाकुर',
#  'BHARATDWAJ PINGAL BARUAH',
#  'Alok S. Chaudhari',
#  'Purendra Singh 🇮🇳',
#  'Anurag patel',
#  'Malti Sharma',
#  'Arkesh Singh Deo',
#  'Apoorva Verma',
#  'बेटी है अनमोल',
#  'Naradas Umesh',
#  'Prabhakar',
#  'KennedyMarriappan',
#  'Devraj Choudhary ( मोदी का परिवार )',
#  'Lavanya Ballal Jain official',
#  'rounak Sharma ',
#  'A.Deiva Nayagam',
#  'Mahila Morcha M P',
#  'Abvp Ghumarwin',
#  'Dr. Jayantibhai Rana',
#  'VATSAL M SHAH',
#  'Mrigen Sarania',
#  'Abdul Riyaz Sahukar',
#  'Shiv Kumar Singh Maurya 🇮🇳',
#  'Piyush Mishra 🇮🇳',
#  'Rajeev',
#  'V.Tribhuvan',
#  'Manish Tiwari.',
#  'ANUJ PRADHAN',
#  'Shah Alamgir',
#  'Dipambit Roy(Papai)',
#  'Pradyut Bordoloi',
#  'anilkumartrs',
#  'Pooja Prajapati',
#  'Bjp Malim Zameer',
#  'Shraddha Rajput',
#  'shubham gabhane',
#  'Abu Tameem',
#  'Trsv Ramesh Peddamma',
#  'Haji Arfat Shaikh - हाजी अरफात शेख',
#  'rakesh sinha',
#  'Ashok Koul (Modi Ka Parivar)',
#  'Ajay Sah',
#  'Gopi Krishna Nema',
#  'Mahesh Barot Gota',
#  'Syed Khalid Ahmed | سید خالد احمد | B.E, LL.B',
#  'INC Babu Lal Ravi #में_भी_राहुलगांधी',
#  'Ch. Kanwar Singh Tanwar',
#  'Ashish gupta',
#  'aniket jawarkar',
#  'Dr Mahipalsinh Gadhavi',
#  'PAMO ( Pavan modi )',
#  'Swami Gursimran Singh Mand',
#  'महेश तपासे Mahesh Tapasey',
#  'Dr.Jahanzaib Sirwal',
#  'Anil K Antony',
#  'Kalubhai Chavda',
#  'Rajesh Nirmal राजेश निर्मल',
#  'Hemaranjan Barik',
#  'Yash Satpute 🇮🇳',
#  'Amod Kumar BJPM',
#  'Dr DHARMVEER TIWARI (मोदी का परिवार)',
#  'Aniket Nikam',
#  'Dr. Sunil Deshmukh',
#  'Pawan Yadav (Rewari)',
#  'Manoj Sharma',
#  'Ramesh Valiya',
#  'Jameel Ahmed Khan',
#  'Office of Dr. Ashwathnarayan',
#  'Anandhan.M',
#  'Aditi Singh',
#  'Chairman KGS Shobhana🆕',
#  'कुलदीप शर्मा',
#  'Goa Pradesh Mahila Congress',
#  'Amit Kamble',
#  'Karai Sakthi',
#  'Narender Paull Bittu',
#  'Md. Nadimul Haque',
#  'Anandh Jose',
#  'greeshma kavali',
#  'Dr Mahes Raja',
#  'MMDA SURESH',
#  'Rakesh chakravorty',
#  'Anil K Shastri',
#  'Juber Ahmed Khan',
#  'Ankit Rathod Namli',
#  'KPYCC',
#  'Raju Sharma ‘ kaushik’',
#  'AIPC Rajasthan',
#  'ம.கலைச்செல்வன் பெரம்பலூர்',
#  'Chitra Sarwara चित्रा सरवारा',
#  'Dr R H LATA 🌐',
#  'Sangli Congress',
#  'INC Abhilash Reddy S',
#  'KUMBAKONAM AYC IYC',
#  'Hemanth Annadurai',
#  'Motha Rohit Mudiraj',
#  'Amit Narang',
#  'Anil Chaudhary',
#  'Harshit Sharma BJP',
#  'adnan khan lodhi',
#  'Hemendrasinh solanki 🇮🇳',
#  'Erode N P Palanisamy',
#  'CYSS - AAP Student Wing',
#  'Manthan Panchal',
#  'DILEEP REDDY KEESARA',
#  'pritesh khambhu',
#  'Anjali yadav',
#  'Adv. Dhanaraj G',
#  'Jamtara Congress Sevadal',
#  'Sasikumar.G',
#  'Sunil Yadav 🇮🇳',
#  'Adv Sohan lal Meghawal',
#  'Parvinder Dhingra',
#  'Karthidmk Mdu',
#  'AAP AMBALA TEAM',
#  'ABVP PU Chandigarh',
#  'Adv Kamaraj',
#  'ℝ𝕚𝕘𝕙𝕥 𝔸ℝ𝕌𝕃',
#  'BJP IT CELL NOIDA',
#  'Anisurrahman',
#  'OFFICE_MLA-BARDOLI',
#  'Vikram Duhan',
#  'Pralhad Joshi',
#  'अभय कुशवाहा विधायक',
#  'DR PRIYABRATA MAJHI',
#  'Yeluri SambasivaRao',
#  'Sujeet Paswan🇮🇳',
#  'rishimaniaWITH_RG',
#  'Rajpurohit Poonam',
#  'Sundaresh H S',
#  'PRAKASH ANDADE (BJP)',
#  'Manish Thakuriya',
#  'Theodore Kiro',
#  'Abdul Waris (Saddam Hussain)',
#  'Leader, BJP UP State',
#  'DeV PaRmaR',
#  'Ashish Chaturvedi',
#  'Syed Ahmed Lateef سيد أحمد لطیف',
#  'Pallab Jyoti Nath',
#  'Santosh Yadav BJP',
#  'Sandip Joshi',
#  'Amitabh Bhattacharjee',
#  'Ashok Buwaniwala',
#  'j',
#  'IYCMadipurassembly',
#  'BJD Keonjhar',
#  'rajesh manni',
#  'अजय मिश्र',
#  'Dr. Preeti डॉ प्रीति',
#  'Dr. Mahendra Singh',
#  'PRITESH SAHU',
#  'Income Tax India',
#  'Fahad Chaus ncp jalna',
#  'Bhuvneshwari kapoor',
#  'Dudi Srikanth Reddy',
#  'RAJENDRA MEHARA',
#  'Chowkidar Swami Sumedhanand',
#  'Pranlal Namori',
#  'Ramniwas Bugaliya',
#  'Aviral Mishra',
#  'Ramzan Chaudhary Official',
#  'Haroon Rasheed',
#  'Kandarp Patel',
#  'Gajendra Nagre',
#  'Adv Sudhir Pataskar',
#  'Tilak Thakur',
#  'Caukidar Arakshita Padhan',
#  'Navanee perumal. social media,',
#  'hardik mangukiya',
#  'Ajitesh Shrivastav ( मोदी का परिवार )',
#  'Nawal Kishor Yadav',
#  'Mansingh Solanki (Modi ka parivar)',
#  'Shubham chikhalkar',
#  'கருமாபுரம்சுரேஷ்',
#  'Praja Sankalpa Yatra',
#  'muslim league',
#  'Hemant Takle',
#  "नीरज अवस्थी 'निर्मल",
#  'Huzefa Hakimuddin Bohra',
#  'Deepti Bhardwaj',
#  'Sandeep Krishniya',
#  'Ritobroto Banerjee',
#  'VK.Moorthy ExArmyBJP',
#  'Parag Sharma',
#  'BIPIN KUMAR SINHA',
#  'Elias Ahmed',
#  'Ahmad',
#  'Dr. Jayant Jigyasu',
#  'Sumeet srivastava',
#  'Vipin Wankhede',
#  'Lalrintluanga Jahau',
#  'B. Jayanth kumar',
#  'BJP Haveri',
#  'Singrauli Congress Sevadal',
#  'Raj Mandapwala',
#  'Kirti Rajgor',
#  'Nikhil Yadav',
#  'Veerabhadra Nayaka',
#  'Assam Congress',
#  'BJP4UDUPI',
#  ...}
